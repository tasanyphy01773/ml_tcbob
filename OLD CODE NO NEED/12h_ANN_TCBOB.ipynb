# %%
import xarray as xr
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import cartopy.feature as cf
import cartopy.crs as ccrs
import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point

# %%
dataset = pd.read_csv('/media/sany/SSD/Document/Project_research/Climate/ML_CYCLONE/Data/April 12 Final (6-24)Date_added - Finaldata1979-2020116.csv')
dataset
# Out:
#       Cyclone No                 Date  hours      minMSL    Maxwind    lat  \
# 0              1  1979-05-07 22:00:00      1   99568.805  17.309776   6.75
# 1              1  1979-05-07 23:00:00      2   99571.960  15.422698   6.75
# 2              1   1979-05-08 0:00:00      3   99591.305  15.190290   6.75
# 3              1   1979-05-08 1:00:00      4   99651.000  15.313608   6.75
# 4              1   1979-05-08 2:00:00      5   99684.900  15.582188   6.75
# ...          ...                  ...    ...         ...        ...    ...
# 4433          55   2020-11-26 5:00:00     46  100028.670  18.663320  13.00
# 4434          55   2020-11-26 6:00:00     47  100032.140  18.751280  13.25
# 4435          55   2020-11-26 7:00:00     48   99978.140  18.789482  13.25
# 4436          55   2020-11-26 8:00:00     49   99899.230  18.364544  13.50
# 4437          55   2020-11-26 9:00:00     50   99867.210  18.106651  13.50
#
#         lon  lat+1  lon+1  lat+2  ...  lat+5  lon+5  lat+6  lon+6  lat+12  \
# 0     86.50   6.75  86.25   6.75  ...   6.75  86.00   6.75  86.00    6.50
# 1     86.25   6.75  86.25   6.75  ...   6.75  86.00   6.75  85.75    6.25
# 2     86.25   6.75  86.00   6.75  ...   6.75  85.75   6.75  86.00    6.25
# 3     86.00   6.75  86.00   6.75  ...   6.75  86.00   6.75  86.00    6.50
# 4     86.00   6.75  86.00   6.75  ...   6.75  86.00   6.75  86.00    6.50
# ...     ...    ...    ...    ...  ...    ...    ...    ...    ...     ...
# 4433  79.75  13.25  79.75  13.25  ...    NaN    NaN    NaN    NaN     NaN
# 4434  79.75  13.25  79.50  13.50  ...    NaN    NaN    NaN    NaN     NaN
# 4435  79.50  13.50  79.75  13.50  ...    NaN    NaN    NaN    NaN     NaN
# 4436  79.75  13.50  79.50    NaN  ...    NaN    NaN    NaN    NaN     NaN
# 4437  79.50    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN     NaN
#
#       lon+12  lat+18  lon+18  lat+24  lon+24
# 0      86.00    6.50   86.00    7.75   86.25
# 1      86.00    6.75   86.00    7.75   86.25
# 2      86.00    6.75   86.25    8.00   86.25
# 3      85.75    7.00   86.50    8.00   86.25
# 4      86.00    7.25   86.50    8.00   86.25
# ...      ...     ...     ...     ...     ...
# 4433     NaN     NaN     NaN     NaN     NaN
# 4434     NaN     NaN     NaN     NaN     NaN
# 4435     NaN     NaN     NaN     NaN     NaN
# 4436     NaN     NaN     NaN     NaN     NaN
# 4437     NaN     NaN     NaN     NaN     NaN
#
# [4438 rows x 25 columns]

# %%
dataset.iloc[:,[0,2,3,4,5,6]]
# Out:
#       Cyclone No  hours      minMSL    Maxwind    lat    lon
# 0              1      1   99568.805  17.309776   6.75  86.50
# 1              1      2   99571.960  15.422698   6.75  86.25
# 2              1      3   99591.305  15.190290   6.75  86.25
# 3              1      4   99651.000  15.313608   6.75  86.00
# 4              1      5   99684.900  15.582188   6.75  86.00
# ...          ...    ...         ...        ...    ...    ...
# 4433          55     46  100028.670  18.663320  13.00  79.75
# 4434          55     47  100032.140  18.751280  13.25  79.75
# 4435          55     48   99978.140  18.789482  13.25  79.50
# 4436          55     49   99899.230  18.364544  13.50  79.75
# 4437          55     50   99867.210  18.106651  13.50  79.50
#
# [4438 rows x 6 columns]

# %%
#select features and target
#X = dataset.iloc[:,[0,1,2,3,4,11]].values
X = dataset.iloc[:,[0,2,3,4,5,6]].values  #for 12 hours prediction
Y = np.column_stack((dataset['lon+12'], dataset['lat+12']))

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')
X = imputer.fit_transform(X)
Y = imputer.fit_transform(Y)

# %%
Y
# Out:
# array([[86.        ,  6.5       ],
#        [86.        ,  6.25      ],
#        [86.        ,  6.25      ],
#        ...,
#        [86.7444415 , 16.70692165],
#        [86.7444415 , 16.70692165],
#        [86.7444415 , 16.70692165]])

# %%
# Convert in numeric 
from sklearn.preprocessing import LabelEncoder
le_date = LabelEncoder()
#X[:,1] = le_date.fit_transform(X[:,1])

# %%
# feature scaling 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
print(X)
print("-----------------------------------------------------------------")
print(Y)
# Out:
# [[-1.73798725e+00 -1.41957570e+00  7.41379446e-01 ... -2.57590622e-01
#   -2.59770058e+00 -2.55110196e-01]
#  [-1.73798725e+00 -1.38751489e+00  7.45289949e-01 ... -2.57590622e-01
#   -2.59770058e+00 -3.32106205e-01]
#  [-1.73798725e+00 -1.35545408e+00  7.69267344e-01 ... -3.33996020e-01
#   -2.59770058e+00 -2.55110196e-01]
#  ...
#  [ 1.62763127e+00  8.72822618e-02  1.24873468e+00 ...  0.00000000e+00
#   -9.41183055e-16 -4.37671642e-15]
#  [ 1.62763127e+00  1.19343069e-01  1.15092872e+00 ...  0.00000000e+00
#   -9.41183055e-16 -4.37671642e-15]
#  [ 1.62763127e+00  1.51403877e-01  1.11124114e+00 ...  0.00000000e+00
#   -9.41183055e-16 -4.37671642e-15]]
# -----------------------------------------------------------------
# [[86.          6.5       ]
#  [86.          6.25      ]
#  [86.          6.25      ]
#  ...
#  [86.7444415  16.70692165]
#  [86.7444415  16.70692165]
#  [86.7444415  16.70692165]]

# %%
# information
print("Total number of Cyclone:" + str(dataset["Cyclone No"][4437]))
print("--------------------------")
print(dataset["Cyclone No"][3098:3100])
# Out:
# Total number of Cyclone:55
# --------------------------
# 3098    40
# 3099    41
# Name: Cyclone No, dtype: int64

# %%
X[:2]
# Out:
# array([[-1.73798725, -1.4195757 ,  0.74137945, -0.67300485, -2.41235007,
#         -0.12350485, -2.44133926, -0.19432021, -2.47086912, -0.19124124,
#         -2.50068168, -0.26316801, -2.53230083, -0.26038189, -2.56466213,
#         -0.25759062, -2.59770058, -0.2551102 ],
#        [-1.73798725, -1.38751489,  0.74528995, -1.20909391, -2.41235007,
#         -0.19702792, -2.44133926, -0.19432021, -2.47086912, -0.26588206,
#         -2.50068168, -0.26316801, -2.53230083, -0.26038189, -2.56466213,
#         -0.25759062, -2.59770058, -0.33210621]])

# %%
# Splitting without randomize
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
k = 3098 #index for 40'th cyclone

X_train = X[:k,:]
X_test = X[k:,:]    

Y_train = Y[:k]    
Y_test= Y[k:]

# %%
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import mean_squared_error

#X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=10)

# %% [markdown]
# ## ANN Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import linear, relu, sigmoid

# %%
print("X_train.shape, Y_train.shape, X_test.shape, Y_train.shape")
print(X_train.shape,Y_train.shape,X_test.shape,Y_train.shape)
# Out:
# X_train.shape, Y_train.shape, X_test.shape, Y_train.shape
# (3098, 18) (3098, 2) (1340, 18) (3098, 2)

# %%
#model.summary()
#[layer1, layer2, layer3, layer4] = model.layers

# Examine Weights shapes
#W1,b1 = layer1.get_weights()
#W2,b2 = layer2.get_weights()
#W3,b3 = layer3.get_weights()

#print(f"W1 shape = {W1.shape}, b1 shape = {b1.shape}")
#print(f"W2 shape = {W2.shape}, b2 shape = {b2.shape}")
#print(f"W3 shape = {W3.shape}, b3 shape = {b3.shape}")

# %%
from keras.callbacks import EarlyStopping

# Define early stopping criteria
early_stop = EarlyStopping(monitor='val_loss', patience=20,verbose=1, mode='min')

# Define model 
model = Sequential([
    tf.keras.Input((X_train.shape[1]),),
    Dense(units=100, kernel_regularizer=tf.keras.regularizers.l2(0.002), activation='relu', name='L1'),
    Dense(units=50, kernel_regularizer=tf.keras.regularizers.l2(0.002), activation='relu', name='L2'), 
    Dense(units=2, activation='linear', name='L3'),
], name='my_model')

# Compile model
model.compile(
    loss=tf.keras.losses.Huber(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=['mean_absolute_error']
)

# Fit model with early stopping
history = model.fit(X_train, Y_train, validation_split=0.33, epochs=100, batch_size=32, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 65/65 [==============================] - 0s 2ms/step - loss: 47.4310 - mean_absolute_error: 47.7286 - val_loss: 40.3175 - val_mean_absolute_error: 40.5918
# Epoch 2/100
# 65/65 [==============================] - 0s 1ms/step - loss: 26.5380 - mean_absolute_error: 26.7660 - val_loss: 16.5015 - val_mean_absolute_error: 16.6738
# Epoch 3/100
# 65/65 [==============================] - 0s 1ms/step - loss: 11.5522 - mean_absolute_error: 11.7179 - val_loss: 15.3514 - val_mean_absolute_error: 15.5259
# Epoch 4/100
# 65/65 [==============================] - 0s 970us/step - loss: 9.0629 - mean_absolute_error: 9.2259 - val_loss: 16.1220 - val_mean_absolute_error: 16.3081
# Epoch 5/100
# 65/65 [==============================] - 0s 1ms/step - loss: 7.3015 - mean_absolute_error: 7.4614 - val_loss: 16.5351 - val_mean_absolute_error: 16.7245
# Epoch 6/100
# 65/65 [==============================] - 0s 950us/step - loss: 6.1790 - mean_absolute_error: 6.3331 - val_loss: 15.9683 - val_mean_absolute_error: 16.1609
# Epoch 7/100
# 65/65 [==============================] - 0s 1ms/step - loss: 5.3272 - mean_absolute_error: 5.4750 - val_loss: 13.6178 - val_mean_absolute_error: 13.8103
# Epoch 8/100
# 65/65 [==============================] - 0s 1ms/step - loss: 4.6183 - mean_absolute_error: 4.7597 - val_loss: 11.5912 - val_mean_absolute_error: 11.7780
# Epoch 9/100
# 65/65 [==============================] - 0s 997us/step - loss: 3.9201 - mean_absolute_error: 4.0540 - val_loss: 9.7018 - val_mean_absolute_error: 9.8858
# Epoch 10/100
# 65/65 [==============================] - 0s 976us/step - loss: 3.2504 - mean_absolute_error: 3.3804 - val_loss: 7.5322 - val_mean_absolute_error: 7.6994
# Epoch 11/100
# 65/65 [==============================] - 0s 919us/step - loss: 2.6139 - mean_absolute_error: 2.7245 - val_loss: 5.5695 - val_mean_absolute_error: 5.7118
# Epoch 12/100
# 65/65 [==============================] - 0s 952us/step - loss: 2.0606 - mean_absolute_error: 2.1583 - val_loss: 3.7926 - val_mean_absolute_error: 3.9206
# Epoch 13/100
# 65/65 [==============================] - 0s 1ms/step - loss: 1.5340 - mean_absolute_error: 1.6164 - val_loss: 2.7367 - val_mean_absolute_error: 2.8664
# Epoch 14/100
# 65/65 [==============================] - 0s 1ms/step - loss: 1.1990 - mean_absolute_error: 1.2657 - val_loss: 2.1902 - val_mean_absolute_error: 2.3081
# Epoch 15/100
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0083 - mean_absolute_error: 1.0533 - val_loss: 1.9833 - val_mean_absolute_error: 2.0902
# Epoch 16/100
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9231 - mean_absolute_error: 0.9616 - val_loss: 1.8540 - val_mean_absolute_error: 1.9483
# Epoch 17/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8555 - mean_absolute_error: 0.8858 - val_loss: 1.7220 - val_mean_absolute_error: 1.8152
# Epoch 18/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8272 - mean_absolute_error: 0.8563 - val_loss: 1.6532 - val_mean_absolute_error: 1.7494
# Epoch 19/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7742 - mean_absolute_error: 0.7959 - val_loss: 1.5214 - val_mean_absolute_error: 1.6117
# Epoch 20/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7635 - mean_absolute_error: 0.7906 - val_loss: 1.5227 - val_mean_absolute_error: 1.6190
# Epoch 21/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7324 - mean_absolute_error: 0.7570 - val_loss: 1.4076 - val_mean_absolute_error: 1.4837
# Epoch 22/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7138 - mean_absolute_error: 0.7384 - val_loss: 1.5554 - val_mean_absolute_error: 1.6718
# Epoch 23/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7003 - mean_absolute_error: 0.7224 - val_loss: 1.4638 - val_mean_absolute_error: 1.5680
# Epoch 24/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6923 - mean_absolute_error: 0.7178 - val_loss: 1.4363 - val_mean_absolute_error: 1.5389
# Epoch 25/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6964 - mean_absolute_error: 0.7306 - val_loss: 1.3637 - val_mean_absolute_error: 1.4681
# Epoch 26/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6932 - mean_absolute_error: 0.7320 - val_loss: 1.4194 - val_mean_absolute_error: 1.5307
# Epoch 27/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6764 - mean_absolute_error: 0.7133 - val_loss: 1.4386 - val_mean_absolute_error: 1.5550
# Epoch 28/100
# 65/65 [==============================] - 0s 996us/step - loss: 0.6816 - mean_absolute_error: 0.7292 - val_loss: 1.3275 - val_mean_absolute_error: 1.4373
# Epoch 29/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6719 - mean_absolute_error: 0.7139 - val_loss: 1.3016 - val_mean_absolute_error: 1.4105
# Epoch 30/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6475 - mean_absolute_error: 0.6888 - val_loss: 1.4127 - val_mean_absolute_error: 1.5360
# Epoch 31/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6397 - mean_absolute_error: 0.6793 - val_loss: 1.3728 - val_mean_absolute_error: 1.5011
# Epoch 32/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6195 - mean_absolute_error: 0.6532 - val_loss: 1.3207 - val_mean_absolute_error: 1.4417
# Epoch 33/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6291 - mean_absolute_error: 0.6738 - val_loss: 1.3047 - val_mean_absolute_error: 1.4310
# Epoch 34/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6087 - mean_absolute_error: 0.6478 - val_loss: 1.3135 - val_mean_absolute_error: 1.4362
# Epoch 35/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6045 - mean_absolute_error: 0.6470 - val_loss: 1.2632 - val_mean_absolute_error: 1.3837
# Epoch 36/100
# 65/65 [==============================] - 0s 964us/step - loss: 0.6070 - mean_absolute_error: 0.6543 - val_loss: 1.3172 - val_mean_absolute_error: 1.4584
# Epoch 37/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6163 - mean_absolute_error: 0.6712 - val_loss: 1.2198 - val_mean_absolute_error: 1.3326
# Epoch 38/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6428 - mean_absolute_error: 0.7188 - val_loss: 1.2908 - val_mean_absolute_error: 1.4208
# Epoch 39/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6137 - mean_absolute_error: 0.6743 - val_loss: 1.3152 - val_mean_absolute_error: 1.4517
# Epoch 40/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6125 - mean_absolute_error: 0.6811 - val_loss: 1.2253 - val_mean_absolute_error: 1.3514
# Epoch 41/100
# 65/65 [==============================] - 0s 985us/step - loss: 0.5837 - mean_absolute_error: 0.6386 - val_loss: 1.2339 - val_mean_absolute_error: 1.3705
# Epoch 42/100
# 65/65 [==============================] - 0s 994us/step - loss: 0.5817 - mean_absolute_error: 0.6409 - val_loss: 1.2043 - val_mean_absolute_error: 1.3423
# Epoch 43/100
# 65/65 [==============================] - 0s 977us/step - loss: 0.5936 - mean_absolute_error: 0.6617 - val_loss: 1.2483 - val_mean_absolute_error: 1.3980
# Epoch 44/100
# 65/65 [==============================] - 0s 944us/step - loss: 0.5720 - mean_absolute_error: 0.6331 - val_loss: 1.2318 - val_mean_absolute_error: 1.3791
# Epoch 45/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5719 - mean_absolute_error: 0.6382 - val_loss: 1.2363 - val_mean_absolute_error: 1.3743
# Epoch 46/100
# 65/65 [==============================] - 0s 2ms/step - loss: 0.5748 - mean_absolute_error: 0.6448 - val_loss: 1.3120 - val_mean_absolute_error: 1.4620
# Epoch 47/100
# 65/65 [==============================] - 0s 2ms/step - loss: 0.5741 - mean_absolute_error: 0.6438 - val_loss: 1.2387 - val_mean_absolute_error: 1.3968
# Epoch 48/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5710 - mean_absolute_error: 0.6446 - val_loss: 1.1979 - val_mean_absolute_error: 1.3327
# Epoch 49/100
# 65/65 [==============================] - 0s 948us/step - loss: 0.5718 - mean_absolute_error: 0.6482 - val_loss: 1.1917 - val_mean_absolute_error: 1.3327
# Epoch 50/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5760 - mean_absolute_error: 0.6580 - val_loss: 1.1514 - val_mean_absolute_error: 1.2878
# Epoch 51/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5429 - mean_absolute_error: 0.6102 - val_loss: 1.1681 - val_mean_absolute_error: 1.3135
# Epoch 52/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5583 - mean_absolute_error: 0.6350 - val_loss: 1.2883 - val_mean_absolute_error: 1.4519
# Epoch 53/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5877 - mean_absolute_error: 0.6843 - val_loss: 1.1530 - val_mean_absolute_error: 1.2967
# Epoch 54/100
# 65/65 [==============================] - 0s 979us/step - loss: 0.5442 - mean_absolute_error: 0.6189 - val_loss: 1.2093 - val_mean_absolute_error: 1.3637
# Epoch 55/100
# 65/65 [==============================] - 0s 953us/step - loss: 0.5398 - mean_absolute_error: 0.6191 - val_loss: 1.1524 - val_mean_absolute_error: 1.2979
# Epoch 56/100
# 65/65 [==============================] - 0s 990us/step - loss: 0.5354 - mean_absolute_error: 0.6096 - val_loss: 1.1337 - val_mean_absolute_error: 1.2889
# Epoch 57/100
# 65/65 [==============================] - 0s 971us/step - loss: 0.5417 - mean_absolute_error: 0.6266 - val_loss: 1.0985 - val_mean_absolute_error: 1.2437
# Epoch 58/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5309 - mean_absolute_error: 0.6075 - val_loss: 1.1890 - val_mean_absolute_error: 1.3537
# Epoch 59/100
# 65/65 [==============================] - 0s 919us/step - loss: 0.5372 - mean_absolute_error: 0.6231 - val_loss: 1.1889 - val_mean_absolute_error: 1.3507
# Epoch 60/100
# 65/65 [==============================] - 0s 989us/step - loss: 0.5390 - mean_absolute_error: 0.6268 - val_loss: 1.1847 - val_mean_absolute_error: 1.3483
# Epoch 61/100
# 65/65 [==============================] - 0s 976us/step - loss: 0.5230 - mean_absolute_error: 0.6076 - val_loss: 1.1164 - val_mean_absolute_error: 1.2691
# Epoch 62/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5158 - mean_absolute_error: 0.5943 - val_loss: 1.1260 - val_mean_absolute_error: 1.2811
# Epoch 63/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5173 - mean_absolute_error: 0.5997 - val_loss: 1.1039 - val_mean_absolute_error: 1.2613
# Epoch 64/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5099 - mean_absolute_error: 0.5904 - val_loss: 1.0881 - val_mean_absolute_error: 1.2486
# Epoch 65/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5352 - mean_absolute_error: 0.6374 - val_loss: 1.1060 - val_mean_absolute_error: 1.2676
# Epoch 66/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5242 - mean_absolute_error: 0.6232 - val_loss: 1.1432 - val_mean_absolute_error: 1.3045
# Epoch 67/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5285 - mean_absolute_error: 0.6305 - val_loss: 1.1527 - val_mean_absolute_error: 1.3136
# Epoch 68/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5139 - mean_absolute_error: 0.6100 - val_loss: 1.1218 - val_mean_absolute_error: 1.2849
# Epoch 69/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5095 - mean_absolute_error: 0.6057 - val_loss: 1.1214 - val_mean_absolute_error: 1.2887
# Epoch 70/100
# 65/65 [==============================] - 0s 967us/step - loss: 0.4957 - mean_absolute_error: 0.5829 - val_loss: 1.1080 - val_mean_absolute_error: 1.2799
# Epoch 71/100
# 65/65 [==============================] - 0s 947us/step - loss: 0.5045 - mean_absolute_error: 0.6023 - val_loss: 1.2152 - val_mean_absolute_error: 1.3996
# Epoch 72/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5204 - mean_absolute_error: 0.6292 - val_loss: 1.1216 - val_mean_absolute_error: 1.2953
# Epoch 73/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4999 - mean_absolute_error: 0.5970 - val_loss: 1.0683 - val_mean_absolute_error: 1.2290
# Epoch 74/100
# 65/65 [==============================] - 0s 982us/step - loss: 0.4938 - mean_absolute_error: 0.5911 - val_loss: 1.1002 - val_mean_absolute_error: 1.2694
# Epoch 75/100
# 65/65 [==============================] - 0s 967us/step - loss: 0.5029 - mean_absolute_error: 0.6085 - val_loss: 1.1289 - val_mean_absolute_error: 1.3055
# Epoch 76/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5059 - mean_absolute_error: 0.6174 - val_loss: 1.1214 - val_mean_absolute_error: 1.2974
# Epoch 77/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4968 - mean_absolute_error: 0.6010 - val_loss: 1.0609 - val_mean_absolute_error: 1.2304
# Epoch 78/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4993 - mean_absolute_error: 0.6119 - val_loss: 1.0862 - val_mean_absolute_error: 1.2701
# Epoch 79/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4839 - mean_absolute_error: 0.5862 - val_loss: 1.0784 - val_mean_absolute_error: 1.2517
# Epoch 80/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4898 - mean_absolute_error: 0.5966 - val_loss: 1.0937 - val_mean_absolute_error: 1.2841
# Epoch 81/100
# 65/65 [==============================] - 0s 944us/step - loss: 0.4902 - mean_absolute_error: 0.6005 - val_loss: 1.0781 - val_mean_absolute_error: 1.2526
# Epoch 82/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4873 - mean_absolute_error: 0.5949 - val_loss: 1.0557 - val_mean_absolute_error: 1.2382
# Epoch 83/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4758 - mean_absolute_error: 0.5795 - val_loss: 1.1037 - val_mean_absolute_error: 1.2814
# Epoch 84/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4830 - mean_absolute_error: 0.5943 - val_loss: 1.0958 - val_mean_absolute_error: 1.2829
# Epoch 85/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4912 - mean_absolute_error: 0.6066 - val_loss: 1.0846 - val_mean_absolute_error: 1.2888
# Epoch 86/100
# 65/65 [==============================] - 0s 993us/step - loss: 0.4737 - mean_absolute_error: 0.5819 - val_loss: 1.0476 - val_mean_absolute_error: 1.2276
# Epoch 87/100
# 65/65 [==============================] - 0s 960us/step - loss: 0.4765 - mean_absolute_error: 0.5878 - val_loss: 1.0590 - val_mean_absolute_error: 1.2396
# Epoch 88/100
# 65/65 [==============================] - 0s 977us/step - loss: 0.4785 - mean_absolute_error: 0.5936 - val_loss: 1.0563 - val_mean_absolute_error: 1.2363
# Epoch 89/100
# 65/65 [==============================] - 0s 956us/step - loss: 0.4822 - mean_absolute_error: 0.6005 - val_loss: 1.0187 - val_mean_absolute_error: 1.2035
# Epoch 90/100
# 65/65 [==============================] - 0s 958us/step - loss: 0.4844 - mean_absolute_error: 0.6075 - val_loss: 1.1291 - val_mean_absolute_error: 1.3336
# Epoch 91/100
# 65/65 [==============================] - 0s 955us/step - loss: 0.4824 - mean_absolute_error: 0.6045 - val_loss: 1.0437 - val_mean_absolute_error: 1.2290
# Epoch 92/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4670 - mean_absolute_error: 0.5826 - val_loss: 1.0451 - val_mean_absolute_error: 1.2263
# Epoch 93/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4662 - mean_absolute_error: 0.5832 - val_loss: 1.1042 - val_mean_absolute_error: 1.3014
# Epoch 94/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4641 - mean_absolute_error: 0.5832 - val_loss: 1.1325 - val_mean_absolute_error: 1.3389
# Epoch 95/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4630 - mean_absolute_error: 0.5835 - val_loss: 1.0567 - val_mean_absolute_error: 1.2407
# Epoch 96/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4547 - mean_absolute_error: 0.5661 - val_loss: 1.0850 - val_mean_absolute_error: 1.2849
# Epoch 97/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4551 - mean_absolute_error: 0.5734 - val_loss: 1.0670 - val_mean_absolute_error: 1.2541
# Epoch 98/100
# 65/65 [==============================] - 0s 959us/step - loss: 0.4455 - mean_absolute_error: 0.5560 - val_loss: 1.1307 - val_mean_absolute_error: 1.3318
# Epoch 99/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4629 - mean_absolute_error: 0.5892 - val_loss: 1.1109 - val_mean_absolute_error: 1.3172
# Epoch 100/100
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4776 - mean_absolute_error: 0.6115 - val_loss: 1.1220 - val_mean_absolute_error: 1.3191

# %%
print(history.history.keys())

# summarize history for accuracy
#with plt.style.context('ggplot'):
plt.figure(dpi=110)
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Mean Absolute error')
plt.ylabel('Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# summarize history for loss
#with plt.style.context('ggplot'):
plt.figure(dpi=110)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
Y_pred = model.predict(X_test)
print(Y_pred[:10])
# Out:
# [[91.661316  18.803469 ]
#  [83.86097    8.916147 ]
#  [84.6655     9.256122 ]
#  [84.98521    9.362993 ]
#  [85.136      9.607234 ]
#  [84.854706   9.515947 ]
#  [84.50323    9.398483 ]
#  [84.251495   9.3154125]
#  [84.09069    9.222548 ]
#  [84.05171    9.219686 ]]

# %%
lon_test = Y_test[:,0]
lat_test = Y_test[:,1]

lon_pred = Y_pred[:,0]
lat_pred = Y_pred[:,1]

random_dataset = pd.DataFrame()
random_dataset['lon_test'] = lon_test
random_dataset['lat_test'] = lat_test

random_dataset['lon_pred'] = lon_pred
random_dataset['lat_pred'] = lat_pred
random_dataset['deviation'] = np.sqrt(((lon_test-lon_pred)**2)+ ((lat_test-lat_pred)**2))

print("  ")
print("The average error for the deviation is "+ str(random_dataset['deviation'].mean()))
print("  ")

random_dataset
# Out:
#
# The average error for the deviation is 1.6433391025201476
#        lon_test   lat_test   lon_pred   lat_pred  deviation
# 0     86.744442  16.706922  91.661316  18.803469   5.345200
# 1     82.500000   8.500000  83.860970   8.916147   1.423171
# 2     82.750000   8.500000  84.665497   9.256122   2.059332
# 3     82.750000   8.500000  84.985207   9.362993   2.396019
# 4     83.000000   8.250000  85.136002   9.607234   2.530729
# ...         ...        ...        ...        ...        ...
# 1335  86.744442  16.706922  86.515724  16.925730   0.316526
# 1336  86.744442  16.706922  86.750786  16.990990   0.284139
# 1337  86.744442  16.706922  86.278915  17.132030   0.630422
# 1338  86.744442  16.706922  86.772095  17.225100   0.518915
# 1339  86.744442  16.706922  87.059082  17.489397   0.843366
#
# [1340 rows x 5 columns]

# %%
import xarray as xr

import cartopy.feature as cf
import cartopy.crs as ccrs
import cartopy.mpl.ticker as cticker
from cartopy.util import add_cyclic_point

fig = plt.figure(figsize=(16,9))
ax = plt.axes(projection=ccrs.PlateCarree())
plt.title("Cyclone track prediction after 6 hours for ANN")


plt.scatter(lon_test, lat_test, label='Test')
plt.scatter(lon_pred, lat_pred, label='Prediction')

ax.coastlines(linewidth=1.4)
ax.gridlines(draw_labels=True)
ax.set_extent([80, 100, 5, 25]) 

plt.legend(loc='upper left')

# %%
plt.figure(figsize=(14,4))
plt.plot(lon_test, label='Lon Test')
plt.plot(lon_pred, label='Lon Predition')
plt.xlabel('Value index')
plt.ylabel('Longitude Value')
plt.ylim(80,100)
plt.title("Longitude prediction with ANN")
plt.legend()

plt.figure(figsize=(14,4))
plt.plot(lat_test, label='Lat Test')
plt.plot(lat_pred, label='Lat Predition')
plt.xlabel('Value index')
plt.ylabel('Latitude Value')
plt.ylim(5, 25)
plt.title("Latitude prediction with ANN")
plt.legend()

# %%
#for single cyclone
#dataset[:21]

# %%
#X_test
